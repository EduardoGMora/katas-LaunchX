# %% [markdown]
# # Ejercicio1 - Utilizar operadores aritméticos

# %% [markdown]
# ## Operadores aritméticos en Python
# Exploremos cómo podemos crear un programa que pueda calcular la distancia entre dos planetas. Comenzaremos usando dos distancias de planetas: Tierra (149.597.870 km) y Júpiter (778.547.200 km).

# %%
# Crear variables para almacenar las dos distancias
# ¡Asegúrate de quitar las comas!

tierra=149597870
jupiter=778547200

distancia=jupiter-tierra
print(distancia)

millas=distancia*0.621
print(int(millas))

# %% [markdown]
# # Ejercicio 2: convierte cadenas en números y usa valores absolutos

# %% [markdown]
# ## Crear una aplicación para trabajar con números y entrada de usuario
# queremos leer la distancia del sol para dos planetas, y luego mostrar la distancia entre los planetas. Haremos esto usando input para leer los valores, int para convertir a entero y luego abs para convertir el resultado en su valor absoluto.

# %%
# Almacenar las entradas del usuario
# Convierte las cadenas de ambos planetas a números enteros
marte=int(input("¿Cuál es la distancia de marte al sol? "))

saturno=int(input("¿Cuál es la distancia de saturno al sol? "))

distanciakm=marte-saturno

print(abs(distanciakm))

distanciamill=distanciakm*0.621
print(abs(distanciamill))
